# %%
import random
subjects = {
    'История и культура заурбежных стран': 5,
    'Экология': 5,
    'Немецкий язык': 5,
    'Физическая культура': 4,
    'Изобразительное искусство и черчение': 4,
    'Русский язык': 4,
    'Экономика': 4,
    'Астрономия': 4,
    'Алгебра': 5,
    'Обществознание': 4,
    'Геометрия': 5,
    'История России': 5,
    'Химия': 5,
    'Литература': 4
}

actor = ('Randolph Scott', '23 January 1898')

popular_name = ["Иван Иванов", "Сергей Сергеев", "Мария Ивановна", "Егор Петров", "Екатерина Смирнова"]
bday = 11
city = ["Сыктывкар"]
full_name = [(random.choice(popular_name), random.choice(city)) for _ in range(30)]

tamandua = "Пушистый Тайник"

#1
average_grade = sum(subjects.values()) / len(subjects)
print("Средняя оценка в аттестате:", average_grade)

#2
unique_name = set(full_name)
print("Уникальные имена:", unique_name)

#3
total_length = sum(len(subject) for subject in subjects)
print("Общая длина всех предметов:", total_length)
#4
unique_letters = set(letter for subject in subjects for letter in subject)
print("Уникальные буквы в названиях предметов:", unique_letters)
#5
tamandua_binary = ''.join(format(ord(char), '08b') for char in tamandua)
print("Имя тамандуа в бинарном виде:", tamandua_binary)

# 6
from datetime import datetime

bday = datetime.strptime(actor[1], '%d %B %Y')
current_date = datetime.now()
days_difference = (current_date - bday).days
print("Количество дней от даты рождения актера до текущей даты:", days_difference)

# 7
from collections import deque

materials_queue = deque()
while True:
    material = input("Введите название стройматериала (для остановки введите 'стоп'): ")
    if material.lower() == "стоп":
        break
    materials_queue.append(material)

print("FIFO очередь стройматериалов:", list(materials_queue))

# 8
emperors_zhou = ["У", "Чэн", "Кан", "Лян", "Сян", "Гун", "Хуань", "Мин", "Ин", "Ай", "Си",
                 "Нонг", "Чжао", "Пинг", "Хуан", "Сюань", "И", "Дань", "Цзянь", "Цзин", "Цзи", "Дао",
                 "Ци", "Лин", "Хуэй"]

index = int(input("Введите индекс: "))

#Проверка на корректность введенного индекса
if index < 1 or index > len(full_name):
    print("Индекс вне диапазона!")
else:
    day = int(input("Введите день рождения: "))
    month = int(input("Введите месяц рождения: "))
    year = int(input("Введите год рождения: "))
    number = (day + month**2 + year) % 39 + 1

    full_name[index-1] = emperors_zhou[number-1]
    print('Готовый список:',full_name)

#9
class Node:
    def __init__(self, data=None):
        self.data = data
        self.next = None

class StrangeTownLinkedList:
    def __init__(self):
        self.head = None

    def append(self, data):
        new_node = Node(data)
        if not self.head:
            self.head = new_node
            return
        current = self.head
        while current.next:
            current = current.next
        current.next = new_node

    def print_list(self):
        current = self.head
        while current:
            print(current.data)
            current = current.next

    def remove(self, town_name):
        current = self.head
        prev = None
        while current:
            if current.data == town_name:
                if prev:
                    prev.next = current.next
                else:
                    self.head = current.next
                current = None
                return
            prev = current
            current = current.next

    def insert(self, town_name, index):
        new_node = Node(town_name)
        current = self.head
        prev = None
        i = 0
        while current and i < index:
            prev = current
            current = current.next
            i += 1
        if prev:
            prev.next = new_node
            new_node.next = current
        else:
            new_node.next = self.head
            self.head = new_node

towns_list = StrangeTownLinkedList()
towns = ["Большая Пысса", "Большие Пупсы", "Манды", "Такое", "Тухлянка", "Баклань", "Лохово", "Факфак", "Большое Струйкино", 
         "Овнище", "Дно", "Трусово", "ул. Забойная", "Кокаиновые горы", "Косяковка", "Куриловка", "Ширяево", "Ломки", "Большой Куяш", 
         "Иннах", "Крутые Хутора", "Крутая", "Новые Алгаши", "Новопозорново", "Лысая Балда", "Болотная Рогавка", "Старые Черви", 
         "Верхнее Зачатье", "Дураково", "Заячий пузырь", "Козявкино", "Цаца", "Засосная", "Звероножка", "Муходоево", "Да-да", "Вобля", 
         "Хреновое", "Блювиничи", "Большое Бухалово", "Свиновье", "Синие Лепяги", "Жабино", "Кончинино", "Раздериха", "Чуваки", "Мусорка", 
         "Голодранкино", "Безводовка", "Красная Могила", "Кундрючья", "Хотелово", "Добрые Пчелы", "Синегубово"]

for town in towns:
    towns_list.append(town)

print("Список странных названий населенных пунктов:")
towns_list.print_list()

town_to_remove = input("Введите название населенного пункта для удаления: ")
towns_list.remove(town_to_remove)
print("Список после удаления:")
towns_list.print_list()

index = int(input("Введите индекс для вставки города 'Конец': "))
towns_list.insert("Конец", index)
print("       Список после вставки города 'Конец':")
towns_list.print_list()
# Out:
# Средняя оценка в аттестате: 4.5
# Уникальные имена: {('Иван Иванов', 'Сыктывкар'), ('Сергей Сергеев', 'Сыктывкар'), ('Екатерина Смирнова', 'Сыктывкар'), ('Мария Ивановна', 'Сыктывкар'), ('Егор Петров', 'Сыктывкар')}
# Общая длина всех предметов: 201
# Уникальные буквы в названиях предметов: {'р', 'б', 'ы', 'и', 'в', 'з', 'т', 'Э', 'с', 'ц', 'й', 'у', 'Н', 'м', 'Х', 'г', 'щ', 'И', 'о', 'я', 'н', 'Р', 'А', 'х', 'е', 'а', 'ж', 'к', 'ч', 'л', 'Г', 'Л', 'ь', 'Ф', ' ', 'О'}
# Имя тамандуа в бинарном виде: 100000111111000100001110001001000100001110001000100000110001000010100010010111000011100100100000100001000101000011000010000111001100001111011000011100010000111010
# Количество дней от даты рождения актера до текущей даты: 46144
# Введите название стройматериала (для остановки введите 'стоп'): кирпич
# Введите название стройматериала (для остановки введите 'стоп'): стоп
# FIFO очередь стройматериалов: ['кирпич']
# Введите индекс: 1
# Введите день рождения: 11
# Введите месяц рождения: 12
# Введите год рождения: 2003
# Готовый список: ['Пинг', ('Сергей Сергеев', 'Сыктывкар'), ('Егор Петров', 'Сыктывкар'), ('Мария Ивановна', 'Сыктывкар'), ('Иван Иванов', 'Сыктывкар'), ('Егор Петров', 'Сыктывкар'), ('Егор Петров', 'Сыктывкар'), ('Сергей Сергеев', 'Сыктывкар'), ('Егор Петров', 'Сыктывкар'), ('Екатерина Смирнова', 'Сыктывкар'), ('Мария Ивановна', 'Сыктывкар'), ('Екатерина Смирнова', 'Сыктывкар'), ('Мария Ивановна', 'Сыктывкар'), ('Мария Ивановна', 'Сыктывкар'), ('Екатерина Смирнова', 'Сыктывкар'), ('Сергей Сергеев', 'Сыктывкар'), ('Егор Петров', 'Сыктывкар'), ('Мария Ивановна', 'Сыктывкар'), ('Иван Иванов', 'Сыктывкар'), ('Мария Ивановна', 'Сыктывкар'), ('Егор Петров', 'Сыктывкар'), ('Иван Иванов', 'Сыктывкар'), ('Иван Иванов', 'Сыктывкар'), ('Иван Иванов', 'Сыктывкар'), ('Мария Ивановна', 'Сыктывкар'), ('Мария Ивановна', 'Сыктывкар'), ('Иван Иванов', 'Сыктывкар'), ('Екатерина Смирнова', 'Сыктывкар'), ('Иван Иванов', 'Сыктывкар'), ('Егор Петров', 'Сыктывкар')]
# Список странных названий населенных пунктов:
# Большая Пысса
# Большие Пупсы
# Манды
# Такое
# Тухлянка
# Баклань
# Лохово
# Факфак
# Большое Струйкино
# Овнище
# Дно
# Трусово
# ул. Забойная
# Кокаиновые горы
# Косяковка
# Куриловка
# Ширяево
# Ломки
# Большой Куяш
# Иннах
# Крутые Хутора
# Крутая
# Новые Алгаши
# Новопозорново
# Лысая Балда
# Болотная Рогавка
# Старые Черви
# Верхнее Зачатье
# Дураково
# Заячий пузырь
# Козявкино
# Цаца
# Засосная
# Звероножка
# Муходоево
# Да-да
# Вобля
# Хреновое
# Блювиничи
# Большое Бухалово
# Свиновье
# Синие Лепяги
# Жабино
# Кончинино
# Раздериха
# Чуваки
# Мусорка
# Голодранкино
# Безводовка
# Красная Могила
# Кундрючья
# Хотелово
# Добрые Пчелы
# Синегубово
# Введите название населенного пункта для удаления: Вобля
# Список после удаления:
# Большая Пысса
# Большие Пупсы
# Манды
# Такое
# Тухлянка
# Баклань
# Лохово
# Факфак
# Большое Струйкино
# Овнище
# Дно
# Трусово
# ул. Забойная
# Кокаиновые горы
# Косяковка
# Куриловка
# Ширяево
# Ломки
# Большой Куяш
# Иннах
# Крутые Хутора
# Крутая
# Новые Алгаши
# Новопозорново
# Лысая Балда
# Болотная Рогавка
# Старые Черви
# Верхнее Зачатье
# Дураково
# Заячий пузырь
# Козявкино
# Цаца
# Засосная
# Звероножка
# Муходоево
# Да-да
# Хреновое
# Блювиничи
# Большое Бухалово
# Свиновье
# Синие Лепяги
# Жабино
# Кончинино
# Раздериха
# Чуваки
# Мусорка
# Голодранкино
# Безводовка
# Красная Могила
# Кундрючья
# Хотелово
# Добрые Пчелы
# Синегубово
# Введите индекс для вставки города 'Конец': 18
#        Список после вставки города 'Конец':
# Большая Пысса
# Большие Пупсы
# Манды
# Такое
# Тухлянка
# Баклань
# Лохово
# Факфак
# Большое Струйкино
# Овнище
# Дно
# Трусово
# ул. Забойная
# Кокаиновые горы
# Косяковка
# Куриловка
# Ширяево
# Ломки
# Конец
# Большой Куяш
# Иннах
# Крутые Хутора
# Крутая
# Новые Алгаши
# Новопозорново
# Лысая Балда
# Болотная Рогавка
# Старые Черви
# Верхнее Зачатье
# Дураково
# Заячий пузырь
# Козявкино
# Цаца
# Засосная
# Звероножка
# Муходоево
# Да-да
# Хреновое
# Блювиничи
# Большое Бухалово
# Свиновье
# Синие Лепяги
# Жабино
# Кончинино
# Раздериха
# Чуваки
# Мусорка
# Голодранкино
# Безводовка
# Красная Могила
# Кундрючья
# Хотелово
# Добрые Пчелы
# Синегубово
